# %%
import pandas as pd
import sqlite3
from pathlib import Path

# Path to data folder
data_dir = Path("data_maps")

# Connect (or create) SQLite database
conn = sqlite3.connect("ads_data.db")
cursor = conn.cursor()

print("Database connected successfully.")
# Out:
# Database connected successfully.

# %%
# Load campaign ID → name
campaign_file = data_dir / "campaign_id_to_name_map.csv"
campaigns = pd.read_csv(campaign_file)

# Save to SQLite
campaigns.to_sql('Campaign', conn, if_exists='replace', index=False)

print("Campaign table created with", len(campaigns), "rows.")
# Out:
# Campaign table created with 14774 rows.

# %%
# Load ad group ID → name
ad_group_file = data_dir / "ad_group_id_to_name_map.csv"
ad_groups = pd.read_csv(ad_group_file)

# Load campaign → ad group mapping (IDs)
camp_ad_group_file = data_dir / "campaign_id_to_ad_group_id_map.csv"
camp_ad_groups = pd.read_csv(camp_ad_group_file)

# Merge to get campaign_id in ad_groups
ad_groups_full = ad_groups.merge(camp_ad_groups, on='Ad Group ID', how='left')

# Save to SQLite
ad_groups_full.to_sql('AdGroup', conn, if_exists='replace', index=False)

print("AdGroup table created with", len(ad_groups_full), "rows.")
# Out:
# AdGroup table created with 20037 rows.

# %%
# Load keyword ID → keyword text
keyword_file = data_dir / "keyword_id_to_name_map.csv"
keywords = pd.read_csv(keyword_file)

# Save to SQLite
keywords.to_sql('Keyword', conn, if_exists='replace', index=False)

print("Keyword table created with", len(keywords), "rows.")
# Out:
# Keyword table created with 638323 rows.

# %%
# Load campaign → negative keyword mapping
neg_kw_file = data_dir / "campaign_to_negative_keyword_mapping.csv"
neg_keywords = pd.read_csv(neg_kw_file)

# Save to SQLite
neg_keywords.to_sql('NegativeKeyword', conn, if_exists='replace', index=False)

print("NegativeKeyword table created with", len(neg_keywords), "rows.")
# Out:
# NegativeKeyword table created with 21710 rows.

# %%
# Load SKU → campaign mapping
sku_campaign_file = data_dir / "sku_to_campaign_name_map.csv"
sku_campaign = pd.read_csv(sku_campaign_file)

# Load ASIN → campaign mapping
asin_campaign_file = data_dir / "asin_informational_only_to_name_map.csv"
asin_campaign = pd.read_csv(asin_campaign_file)

# Clean column names for convenience
sku_campaign.columns = ['sku', 'campaign_name']
asin_campaign.columns = ['asin', 'campaign_name']

# Save SKU table
sku_campaign[['sku']].drop_duplicates().to_sql('SKU', conn, if_exists='replace', index=False)

# Save CampaignSKU mapping
sku_campaign.to_sql('CampaignSKU', conn, if_exists='replace', index=False)

# Save ASIN table
asin_campaign[['asin']].drop_duplicates().to_sql('ASIN', conn, if_exists='replace', index=False)

# Save CampaignASIN mapping
asin_campaign.to_sql('CampaignASIN', conn, if_exists='replace', index=False)

print("SKU, ASIN, CampaignSKU, and CampaignASIN tables created.")
# Out:
# SKU, ASIN, CampaignSKU, and CampaignASIN tables created.

# %%
import pandas as pd
import sqlite3

# Connect to database
conn = sqlite3.connect("ads_data.db")

# Load campaign performance CSV
performance_file = "data/Sponsored_Products_Campaign_L30.csv"  # Replace with your actual file path
df = pd.read_csv(performance_file)

# Optional: clean column names
df.columns = [col.strip().replace(" ", "_").lower() for col in df.columns]

# Create Campaign table
campaign_cols = ['campaign_name', 'portfolio_name', 'program_type', 'retailer',
                 'country', 'status', 'currency', 'budget_amount', 'Average Time in Budget','targeting_type', 'bidding_strategy']

campaign_table = df[campaign_cols].drop_duplicates(subset=['campaign_name'])
campaign_table.to_sql('Campaign', conn, if_exists='replace', index=False)

print("Campaign table populated with", len(campaign_table), "unique campaigns.")
# Out:
# Campaign table populated with 2232 unique campaigns.

# %%
# Select relevant performance metrics
perf_cols = ['campaign_name', 'start_date', 'end_date', 'impressions', 'last_year_impressions',
             'clicks', 'last_year_clicks', 'click-thru_rate_(ctr)', 'spend', 'last_year_spend',
             'cost_per_click_(cpc)', 'last_year_cost_per_click_(cpc)',
             '7_day_total_orders_(#)', 'total_advertising_cost_of_sales_(acos)', 
             'total_return_on_advertising_spend_(roas)', '7_day_total_sales']

perf_table = df[perf_cols]

# Save to SQLite
perf_table.to_sql('CampaignPerformance', conn, if_exists='replace', index=False)

print("CampaignPerformance table created with", len(perf_table), "rows.")
# Out:
# CampaignPerformance table created with 2232 rows.

# %%
search_terms_file = "data/Sponsored_Products_Search_Term_Detailed_L30.xlsx"  # Replace with your file path
df = pd.read_excel(search_terms_file)

# Clean column names for convenience
df.columns = [col.strip().replace(" ", "_").replace("(", "").replace(")", "").lower() for col in df.columns]

print("Columns loaded:", df.columns.tolist())
print("Number of rows:", len(df))
# Out:
# d:\work\n8n-work-flow\.venv\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# Columns loaded: ['date', 'portfolio_name', 'currency', 'campaign_name', 'ad_group_name', 'retailer', 'country', 'targeting', 'match_type', 'customer_search_term', 'impressions', 'clicks', 'click-thru_rate_ctr', 'cost_per_click_cpc', 'spend', '7_day_total_sales', 'total_advertising_cost_of_sales_acos', 'total_return_on_advertising_spend_roas', '7_day_total_orders_#', '7_day_total_units_#', '7_day_conversion_rate', '7_day_advertised_sku_units_#', '7_day_other_sku_units_#', '7_day_advertised_sku_sales', '7_day_other_sku_sales']
# Number of rows: 621867

# %%
# Select relevant columns for performance table
keyword_perf_cols = [
    'date', 'portfolio_name', 'currency', 'campaign_name', 'ad_group_name', 
    'retailer', 'country', 'targeting', 'match_type', 'customer_search_term',
    'impressions', 'clicks', 'click-thru_rate_ctr', 'cost_per_click_cpc', 
    'spend', '7_day_total_sales', 'total_advertising_cost_of_sales_acos', 
    'total_return_on_advertising_spend_roas', '7_day_total_orders_#', 
    '7_day_total_units_#', '7_day_conversion_rate', 
    '7_day_advertised_sku_units_#', '7_day_other_sku_units_#',
    '7_day_advertised_sku_sales', '7_day_other_sku_sales'
]

# Keep only these columns
keyword_perf_table = df[keyword_perf_cols]

# Convert numeric columns to proper types
numeric_cols = [
    'impressions', 'clicks', 'click-thru_rate_ctr', 'cost_per_click_cpc', 
    'spend', '7_day_total_sales', 'total_advertising_cost_of_sales_acos', 
    'total_return_on_advertising_spend_roas', '7_day_total_orders_#', 
    '7_day_total_units_#', '7_day_conversion_rate', 
    '7_day_advertised_sku_units_#', '7_day_other_sku_units_#',
    '7_day_advertised_sku_sales', '7_day_other_sku_sales'
]

for col in numeric_cols:
    keyword_perf_table[col] = pd.to_numeric(keyword_perf_table[col], errors='coerce')

# Save to SQLite
keyword_perf_table.to_sql('KeywordPerformance', conn, if_exists='replace', index=False)

print("KeywordPerformance table created with", len(keyword_perf_table), "rows.")
# Out:
# KeywordPerformance table created with 621867 rows.

# %%
def get_tables_and_columns(db_name):
    """
    Connects to a SQLite database and returns a dictionary where
    keys are table names and values are lists of column names.
    """
    tables_columns = {}
    
    try:
        # Connect to the database
        conn = sqlite3.connect(db_name)
        cursor = conn.cursor()

        # Get all table names
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
        tables = cursor.fetchall()

        for table in tables:
            table_name = table[0]
            # Get column info for each table
            cursor.execute(f"PRAGMA table_info({table_name});")
            columns_info = cursor.fetchall()
            column_names = [col[1] for col in columns_info]  # second field is column name
            tables_columns[table_name] = column_names

        conn.close()
        return tables_columns

    except sqlite3.Error as e:
        print(f"Database error: {e}")
        return None

# Example usage
db_path = "ads_data.db"
result = get_tables_and_columns(db_path)
print(result)
# Out:
# {'AdGroup': ['Ad Group ID', 'Ad Group Name (Informational only)', 'Campaign ID'], 'Keyword': ['Keyword ID', 'Keyword Text'], 'NegativeKeyword': ['campaign_name', 'negative_keyword_text'], 'SKU': ['sku'], 'CampaignSKU': ['sku', 'campaign_name'], 'ASIN': ['asin'], 'CampaignASIN': ['asin', 'campaign_name'], 'Campaign': ['campaign_name', 'portfolio_name', 'program_type', 'retailer', 'country', 'status', 'currency', 'budget_amount', 'targeting_type', 'bidding_strategy'], 'CampaignPerformance': ['campaign_name', 'start_date', 'end_date', 'impressions', 'last_year_impressions', 'clicks', 'last_year_clicks', 'click-thru_rate_(ctr)', 'spend', 'last_year_spend', 'cost_per_click_(cpc)', 'last_year_cost_per_click_(cpc)', '7_day_total_orders_(#)', 'total_advertising_cost_of_sales_(acos)', 'total_return_on_advertising_spend_(roas)', '7_day_total_sales'], 'KeywordPerformance': ['date', 'portfolio_name', 'currency', 'campaign_name', 'ad_group_name', 'retailer', 'country', 'targeting', 'match_type', 'customer_search_term', 'impressions', 'clicks', 'click-thru_rate_ctr', 'cost_per_click_cpc', 'spend', '7_day_total_sales', 'total_advertising_cost_of_sales_acos', 'total_return_on_advertising_spend_roas', '7_day_total_orders_#', '7_day_total_units_#', '7_day_conversion_rate', '7_day_advertised_sku_units_#', '7_day_other_sku_units_#', '7_day_advertised_sku_sales', '7_day_other_sku_sales']}

# %%
import json

def get_campaign_summary(db_path, campaign_name):
    """
    Returns:
    - Campaign performance
    - Campaign portfolio info
    - Keywords used in the campaign (from KeywordPerformance)
    - Keyword performance
    """
    summary = {}

    try:
        conn = sqlite3.connect(db_path)
        cursor = conn.cursor()

        # --- Campaign performance ---
        cursor.execute("""
            SELECT * FROM CampaignPerformance
            WHERE campaign_name = ?
        """, (campaign_name,))
        perf_columns = [desc[0] for desc in cursor.description]
        campaign_perf = cursor.fetchone()
        summary['campaign_performance'] = dict(zip(perf_columns, campaign_perf)) if campaign_perf else None

        # --- Campaign info ---
        cursor.execute("""
            SELECT * FROM Campaign
            WHERE campaign_name = ?
        """, (campaign_name,))
        info_columns = [desc[0] for desc in cursor.description]
        campaign_info = cursor.fetchone()
        summary['campaign_info'] = dict(zip(info_columns, campaign_info)) if campaign_info else None

        # --- Keyword performance (also gives keywords used) ---
        cursor.execute("""
            SELECT * FROM KeywordPerformance
            WHERE campaign_name = ?
        """, (campaign_name,))
        kw_perf_columns = [desc[0] for desc in cursor.description]
        keyword_perf_rows = cursor.fetchall()
        keyword_perf_list = [dict(zip(kw_perf_columns, row)) for row in keyword_perf_rows]
        summary['keyword_performance'] = keyword_perf_list

        # --- Keywords used ---
        # Extract unique customer_search_terms from keyword performance
        keywords_used = list({row['customer_search_term'] for row in keyword_perf_list})
        summary['keywords'] = keywords_used

        conn.close()
        return summary

    except sqlite3.Error as e:
        print(f"Database error: {e}")
        return None

# -------------------------
# Example usage:
# db_path = "your_database.db"
# campaign_name = "My Campaign Name"
# summary = get_campaign_summary(db_path, campaign_name)
# print(summary)
summary = get_campaign_summary('ads_data.db',"UTELT4BT2754-600GMBLACK - Group C")
print(json.dumps(summary, indent=4, sort_keys=True))
# Out:
# {
#     "campaign_info": {
#         "bidding_strategy": "Dynamic bids - down only",
#         "budget_amount": "$30.0",
#         "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#         "country": "United States",
#         "currency": "USD",
#         "portfolio_name": "Towel",
#         "program_type": "Sponsored Products",
#         "retailer": "Amazon",
#         "status": "ENABLED",
#         "targeting_type": "Manual targeting"
#     },
#     "campaign_performance": {
#         "7_day_total_orders_(#)": 76,
#         "7_day_total_sales": "$2964.02",
#         "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#         "click-thru_rate_(ctr)": "1.121%",
#         "clicks": 294,
#         "cost_per_click_(cpc)": "$1.5181973",
#         "end_date": "Jan 04, 2026",
#         "impressions": 26236,
#         "last_year_clicks": null,
#         "last_year_cost_per_click_(cpc)": "$0.0",
#         "last_year_impressions": null,
#         "last_year_spend": null,
#         "spend": "$446.35",
#         "start_date": "Dec 06, 2025",
#         "total_advertising_cost_of_sales_(acos)": "15.059000000000001%",
#         "total_return_on_advertising_spend_(roas)": 6.64
#     },
#     "keyword_performance": [
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.024096385542168676,
#             "clicks": 2,
#             "cost_per_click_cpc": 2.595,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-06 00:00:00",
#             "impressions": 83,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 5.19,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.5,
#             "7_day_other_sku_sales": 28.49,
#             "7_day_other_sku_units_#": 1,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 28.49,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.013513513513513513,
#             "clicks": 2,
#             "cost_per_click_cpc": 2.365,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-07 00:00:00",
#             "impressions": 148,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 4.73,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.16602316602316605,
#             "total_return_on_advertising_spend_roas": 6.0232558139534875
#         },
#         {
#             "7_day_advertised_sku_sales": 34.99,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.5,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 34.99,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.03333333333333333,
#             "clicks": 2,
#             "cost_per_click_cpc": 3.04,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-08 00:00:00",
#             "impressions": 60,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 6.08,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.17376393255215775,
#             "total_return_on_advertising_spend_roas": 5.754934210526316
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.011049723756906075,
#             "clicks": 2,
#             "cost_per_click_cpc": 2.32,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-09 00:00:00",
#             "impressions": 181,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 4.64,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.014184397163120569,
#             "clicks": 2,
#             "cost_per_click_cpc": 2.985,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-10 00:00:00",
#             "impressions": 141,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 5.97,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 31.33,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 1.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 31.33,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.012195121951219513,
#             "clicks": 1,
#             "cost_per_click_cpc": 3.04,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-11 00:00:00",
#             "impressions": 82,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 3.04,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.0970315991062879,
#             "total_return_on_advertising_spend_roas": 10.305921052631579
#         },
#         {
#             "7_day_advertised_sku_sales": 31.33,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.5,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 31.33,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.034482758620689655,
#             "clicks": 2,
#             "cost_per_click_cpc": 1.0,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-12 00:00:00",
#             "impressions": 58,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 2.0,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.06383657835939995,
#             "total_return_on_advertising_spend_roas": 15.665
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.012345679012345678,
#             "clicks": 1,
#             "cost_per_click_cpc": 1.31,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-13 00:00:00",
#             "impressions": 81,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 1.31,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 31.33,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.5,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 31.33,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.010810810810810811,
#             "clicks": 2,
#             "cost_per_click_cpc": 1.2,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-14 00:00:00",
#             "impressions": 185,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 2.4,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.07660389403127993,
#             "total_return_on_advertising_spend_roas": 13.054166666666667
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.00909090909090909,
#             "clicks": 1,
#             "cost_per_click_cpc": 1.09,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-15 00:00:00",
#             "impressions": 110,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 1.09,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 31.33,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.5,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 31.33,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.013605442176870748,
#             "clicks": 2,
#             "cost_per_click_cpc": 1.2,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-16 00:00:00",
#             "impressions": 147,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 2.4,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.07660389403127993,
#             "total_return_on_advertising_spend_roas": 13.054166666666667
#         },
#         {
#             "7_day_advertised_sku_sales": 69.98,
#             "7_day_advertised_sku_units_#": 2,
#             "7_day_conversion_rate": 0.3636363636363637,
#             "7_day_other_sku_sales": 47.14,
#             "7_day_other_sku_units_#": 2,
#             "7_day_total_orders_#": 4,
#             "7_day_total_sales": 117.12,
#             "7_day_total_units_#": 4,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.018612521150592216,
#             "clicks": 11,
#             "cost_per_click_cpc": 2.7945454545454544,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-06 00:00:00",
#             "impressions": 591,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 30.74,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.2624658469945355,
#             "total_return_on_advertising_spend_roas": 3.810019518542616
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.021207177814029365,
#             "clicks": 13,
#             "cost_per_click_cpc": 2.753846153846154,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-07 00:00:00",
#             "impressions": 613,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 35.8,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 34.99,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.1,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 34.99,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.029940119760479042,
#             "clicks": 10,
#             "cost_per_click_cpc": 3.028,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-08 00:00:00",
#             "impressions": 334,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 30.28,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.8653901114604172,
#             "total_return_on_advertising_spend_roas": 1.15554821664465
#         },
#         {
#             "7_day_advertised_sku_sales": 69.98,
#             "7_day_advertised_sku_units_#": 2,
#             "7_day_conversion_rate": 0.21428571428571427,
#             "7_day_other_sku_sales": 29.99,
#             "7_day_other_sku_units_#": 1,
#             "7_day_total_orders_#": 3,
#             "7_day_total_sales": 99.97,
#             "7_day_total_units_#": 3,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.013539651837524178,
#             "clicks": 14,
#             "cost_per_click_cpc": 2.5142857142857147,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-09 00:00:00",
#             "impressions": 1034,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 35.2,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.35210563168950687,
#             "total_return_on_advertising_spend_roas": 2.840056818181818
#         },
#         {
#             "7_day_advertised_sku_sales": 34.99,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.07692307692307693,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 34.99,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.0152046783625731,
#             "clicks": 13,
#             "cost_per_click_cpc": 2.626923076923077,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-10 00:00:00",
#             "impressions": 855,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 34.15,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.9759931408973992,
#             "total_return_on_advertising_spend_roas": 1.0245973645680821
#         },
#         {
#             "7_day_advertised_sku_sales": 31.33,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.5,
#             "7_day_other_sku_sales": 32.99,
#             "7_day_other_sku_units_#": 1,
#             "7_day_total_orders_#": 2,
#             "7_day_total_sales": 64.32,
#             "7_day_total_units_#": 2,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.005856515373352855,
#             "clicks": 4,
#             "cost_per_click_cpc": 2.09,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-11 00:00:00",
#             "impressions": 683,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 8.36,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.12997512437810946,
#             "total_return_on_advertising_spend_roas": 7.693779904306219
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.002162162162162162,
#             "clicks": 2,
#             "cost_per_click_cpc": 1.2,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-12 00:00:00",
#             "impressions": 925,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 2.4,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 31.33,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.8333333333333334,
#             "7_day_other_sku_sales": 135.92,
#             "7_day_other_sku_units_#": 4,
#             "7_day_total_orders_#": 5,
#             "7_day_total_sales": 167.25,
#             "7_day_total_units_#": 5,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.005676442762535477,
#             "clicks": 6,
#             "cost_per_click_cpc": 1.0966666666666667,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-13 00:00:00",
#             "impressions": 1057,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 6.58,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.03934230194319881,
#             "total_return_on_advertising_spend_roas": 25.417933130699087
#         },
#         {
#             "7_day_advertised_sku_sales": 31.33,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.2222222222222222,
#             "7_day_other_sku_sales": 39.99,
#             "7_day_other_sku_units_#": 1,
#             "7_day_total_orders_#": 2,
#             "7_day_total_sales": 71.32,
#             "7_day_total_units_#": 2,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.005921052631578948,
#             "clicks": 9,
#             "cost_per_click_cpc": 1.1555555555555557,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-14 00:00:00",
#             "impressions": 1520,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 10.4,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.14582164890633764,
#             "total_return_on_advertising_spend_roas": 6.857692307692306
#         },
#         {
#             "7_day_advertised_sku_sales": 62.66,
#             "7_day_advertised_sku_units_#": 2,
#             "7_day_conversion_rate": 1.625,
#             "7_day_other_sku_sales": 283.18,
#             "7_day_other_sku_units_#": 11,
#             "7_day_total_orders_#": 13,
#             "7_day_total_sales": 345.84,
#             "7_day_total_units_#": 13,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.005970149253731344,
#             "clicks": 8,
#             "cost_per_click_cpc": 1.095,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-15 00:00:00",
#             "impressions": 1340,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 8.76,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.02532963219986121,
#             "total_return_on_advertising_spend_roas": 39.47945205479452
#         },
#         {
#             "7_day_advertised_sku_sales": 125.32,
#             "7_day_advertised_sku_units_#": 4,
#             "7_day_conversion_rate": 0.3,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 3,
#             "7_day_total_sales": 125.32,
#             "7_day_total_units_#": 4,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.010752688172043012,
#             "clicks": 10,
#             "cost_per_click_cpc": 1.0630000000000002,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-16 00:00:00",
#             "impressions": 930,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 10.63,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.08482285349505267,
#             "total_return_on_advertising_spend_roas": 11.789275634995295
#         },
#         {
#             "7_day_advertised_sku_sales": 31.33,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.25,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 31.33,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.004371584699453552,
#             "clicks": 4,
#             "cost_per_click_cpc": 1.0,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-17 00:00:00",
#             "impressions": 915,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 4.0,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.1276731567187999,
#             "total_return_on_advertising_spend_roas": 7.8325
#         },
#         {
#             "7_day_advertised_sku_sales": 93.99,
#             "7_day_advertised_sku_units_#": 3,
#             "7_day_conversion_rate": 0.25,
#             "7_day_other_sku_sales": 61.94,
#             "7_day_other_sku_units_#": 2,
#             "7_day_total_orders_#": 5,
#             "7_day_total_sales": 155.93,
#             "7_day_total_units_#": 5,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.02089864158829676,
#             "clicks": 20,
#             "cost_per_click_cpc": 1.1179999999999999,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-18 00:00:00",
#             "impressions": 957,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 22.36,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.14339767844545628,
#             "total_return_on_advertising_spend_roas": 6.973613595706619
#         },
#         {
#             "7_day_advertised_sku_sales": 31.33,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.1,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 31.33,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.009107468123861567,
#             "clicks": 10,
#             "cost_per_click_cpc": 1.117,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-19 00:00:00",
#             "impressions": 1098,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 11.17,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.35652729013724865,
#             "total_return_on_advertising_spend_roas": 2.8048343777976723
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.009765625,
#             "clicks": 5,
#             "cost_per_click_cpc": 1.178,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-20 00:00:00",
#             "impressions": 512,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 5.89,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 39.99,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.1,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 39.99,
#             "7_day_total_units_#": 1,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.014285714285714285,
#             "clicks": 10,
#             "cost_per_click_cpc": 1.142,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-21 00:00:00",
#             "impressions": 700,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 11.42,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.28557139284821204,
#             "total_return_on_advertising_spend_roas": 3.501751313485114
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.012106537530266344,
#             "clicks": 5,
#             "cost_per_click_cpc": 1.09,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-22 00:00:00",
#             "impressions": 413,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 5.45,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.01006711409395973,
#             "clicks": 3,
#             "cost_per_click_cpc": 1.09,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-23 00:00:00",
#             "impressions": 298,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 3.27,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.013245033112582781,
#             "clicks": 4,
#             "cost_per_click_cpc": 1.045,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-24 00:00:00",
#             "impressions": 302,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 4.18,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 119.97,
#             "7_day_advertised_sku_units_#": 3,
#             "7_day_conversion_rate": 1.0,
#             "7_day_other_sku_sales": 130.97,
#             "7_day_other_sku_units_#": 3,
#             "7_day_total_orders_#": 4,
#             "7_day_total_sales": 250.94,
#             "7_day_total_units_#": 6,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.00954653937947494,
#             "clicks": 4,
#             "cost_per_click_cpc": 1.045,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-25 00:00:00",
#             "impressions": 419,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 4.18,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.016657368295210008,
#             "total_return_on_advertising_spend_roas": 60.03349282296651
#         },
#         {
#             "7_day_advertised_sku_sales": 104.97,
#             "7_day_advertised_sku_units_#": 3,
#             "7_day_conversion_rate": 0.2,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 3,
#             "7_day_total_sales": 104.97,
#             "7_day_total_units_#": 3,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.022222222222222223,
#             "clicks": 15,
#             "cost_per_click_cpc": 1.078,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-26 00:00:00",
#             "impressions": 675,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 16.17,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.15404401257502146,
#             "total_return_on_advertising_spend_roas": 6.491651205936919
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.3333333333333333,
#             "clicks": 1,
#             "cost_per_click_cpc": 3.04,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels\ufffc",
#             "date": "2025-12-06 00:00:00",
#             "impressions": 3,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 3.04,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.017857142857142856,
#             "clicks": 1,
#             "cost_per_click_cpc": 1.09,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2025-12-31 00:00:00",
#             "impressions": 56,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 1.09,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.01515151515151515,
#             "clicks": 1,
#             "cost_per_click_cpc": 1.09,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towel",
#             "date": "2026-01-02 00:00:00",
#             "impressions": 66,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 1.09,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         },
#         {
#             "7_day_advertised_sku_sales": 69.98,
#             "7_day_advertised_sku_units_#": 2,
#             "7_day_conversion_rate": 0.3333333333333333,
#             "7_day_other_sku_sales": 75.9,
#             "7_day_other_sku_units_#": 2,
#             "7_day_total_orders_#": 3,
#             "7_day_total_sales": 145.88,
#             "7_day_total_units_#": 4,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.014218009478672987,
#             "clicks": 9,
#             "cost_per_click_cpc": 1.09,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-27 00:00:00",
#             "impressions": 633,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 9.81,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.06724705237181246,
#             "total_return_on_advertising_spend_roas": 14.870540265035677
#         },
#         {
#             "7_day_advertised_sku_sales": 34.99,
#             "7_day_advertised_sku_units_#": 1,
#             "7_day_conversion_rate": 0.2,
#             "7_day_other_sku_sales": 35.98,
#             "7_day_other_sku_units_#": 2,
#             "7_day_total_orders_#": 3,
#             "7_day_total_sales": 70.97,
#             "7_day_total_units_#": 3,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.01460564751703992,
#             "clicks": 15,
#             "cost_per_click_cpc": 1.0686666666666667,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-28 00:00:00",
#             "impressions": 1027,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 16.03,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.22587008595181063,
#             "total_return_on_advertising_spend_roas": 4.427323767935121
#         },
#         {
#             "7_day_advertised_sku_sales": 139.96,
#             "7_day_advertised_sku_units_#": 4,
#             "7_day_conversion_rate": 0.5714285714285714,
#             "7_day_other_sku_sales": 37.99,
#             "7_day_other_sku_units_#": 1,
#             "7_day_total_orders_#": 4,
#             "7_day_total_sales": 177.95,
#             "7_day_total_units_#": 5,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.010014306151645207,
#             "clicks": 7,
#             "cost_per_click_cpc": 1.042857142857143,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-29 00:00:00",
#             "impressions": 699,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 7.3,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.04102275920202304,
#             "total_return_on_advertising_spend_roas": 24.376712328767123
#         },
#         {
#             "7_day_advertised_sku_sales": 69.98,
#             "7_day_advertised_sku_units_#": 2,
#             "7_day_conversion_rate": 0.1,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 69.98,
#             "7_day_total_units_#": 2,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.016181229773462782,
#             "clicks": 10,
#             "cost_per_click_cpc": 1.116,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-30 00:00:00",
#             "impressions": 618,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 11.16,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.15947413546727635,
#             "total_return_on_advertising_spend_roas": 6.270609318996416
#         },
#         {
#             "7_day_advertised_sku_sales": 221.94,
#             "7_day_advertised_sku_units_#": 6,
#             "7_day_conversion_rate": 0.2,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 1,
#             "7_day_total_sales": 221.94,
#             "7_day_total_units_#": 6,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.01160092807424594,
#             "clicks": 5,
#             "cost_per_click_cpc": 1.178,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2025-12-31 00:00:00",
#             "impressions": 431,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 5.89,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.02653870415427593,
#             "total_return_on_advertising_spend_roas": 37.68081494057725
#         },
#         {
#             "7_day_advertised_sku_sales": 79.98,
#             "7_day_advertised_sku_units_#": 2,
#             "7_day_conversion_rate": 0.15384615384615385,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 2,
#             "7_day_total_sales": 79.98,
#             "7_day_total_units_#": 2,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.01683937823834197,
#             "clicks": 13,
#             "cost_per_click_cpc": 1.1099999999999999,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2026-01-01 00:00:00",
#             "impressions": 772,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 14.43,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.18042010502625655,
#             "total_return_on_advertising_spend_roas": 5.542619542619543
#         },
#         {
#             "7_day_advertised_sku_sales": 73.98,
#             "7_day_advertised_sku_units_#": 2,
#             "7_day_conversion_rate": 0.16666666666666663,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 2,
#             "7_day_total_sales": 73.98,
#             "7_day_total_units_#": 2,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.01772525849335303,
#             "clicks": 12,
#             "cost_per_click_cpc": 1.0933333333333333,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2026-01-02 00:00:00",
#             "impressions": 677,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 13.12,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.17734522844011896,
#             "total_return_on_advertising_spend_roas": 5.638719512195123
#         },
#         {
#             "7_day_advertised_sku_sales": 184.95,
#             "7_day_advertised_sku_units_#": 5,
#             "7_day_conversion_rate": 0.5555555555555556,
#             "7_day_other_sku_sales": 73.98,
#             "7_day_other_sku_units_#": 2,
#             "7_day_total_orders_#": 5,
#             "7_day_total_sales": 258.93,
#             "7_day_total_units_#": 7,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.01437699680511182,
#             "clicks": 9,
#             "cost_per_click_cpc": 1.1388888888888888,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2026-01-03 00:00:00",
#             "impressions": 626,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 10.25,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": 0.03958598849109798,
#             "total_return_on_advertising_spend_roas": 25.261463414634147
#         },
#         {
#             "7_day_advertised_sku_sales": 0.0,
#             "7_day_advertised_sku_units_#": 0,
#             "7_day_conversion_rate": 0.0,
#             "7_day_other_sku_sales": 0.0,
#             "7_day_other_sku_units_#": 0,
#             "7_day_total_orders_#": 0,
#             "7_day_total_sales": 0.0,
#             "7_day_total_units_#": 0,
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#             "click-thru_rate_ctr": 0.014903129657228018,
#             "clicks": 10,
#             "cost_per_click_cpc": 1.09,
#             "country": "United States",
#             "currency": "USD",
#             "customer_search_term": "black towels",
#             "date": "2026-01-04 00:00:00",
#             "impressions": 671,
#             "match_type": "EXACT",
#             "portfolio_name": "Towel",
#             "retailer": "Amazon",
#             "spend": 10.9,
#             "targeting": "black towels",
#             "total_advertising_cost_of_sales_acos": null,
#             "total_return_on_advertising_spend_roas": 0.0
#         }
#     ],
#     "keywords": [
#         "black towels\ufffc",
#         "black towel",
#         "black towels"
#     ]
# }

# %%
def get_campaign_summary_with_keyword_score(db_path, campaign_name):
    summary = {}

    try:
        conn = sqlite3.connect(db_path)

        # --- Campaign performance ---
        campaign_perf = pd.read_sql_query(
            "SELECT * FROM CampaignPerformance WHERE campaign_name = ?", conn, params=(campaign_name,)
        )
        summary['campaign_performance'] = campaign_perf.to_dict(orient='records')[0] if not campaign_perf.empty else None

        # --- Campaign info ---
        campaign_info = pd.read_sql_query(
            "SELECT * FROM Campaign WHERE campaign_name = ?", conn, params=(campaign_name,)
        )
        summary['campaign_info'] = campaign_info.to_dict(orient='records')[0] if not campaign_info.empty else None

        # --- Keyword performance ---
        kw_perf = pd.read_sql_query(
            "SELECT * FROM KeywordPerformance WHERE campaign_name = ?", conn, params=(campaign_name,)
        )

        if kw_perf.empty:
            summary['keyword_performance'] = []
            summary['keywords'] = []
            conn.close()
            return summary

        # --- Aggregate by keyword ---
        kw_agg = kw_perf.groupby('customer_search_term').agg(
            impressions=pd.NamedAgg(column='impressions', aggfunc='sum'),
            clicks=pd.NamedAgg(column='clicks', aggfunc='sum'),
            spend=pd.NamedAgg(column='spend', aggfunc='sum'),
            sales=pd.NamedAgg(column='7_day_total_sales', aggfunc='sum'),
            orders=pd.NamedAgg(column='7_day_total_orders_#', aggfunc='sum')
        ).reset_index()

        # --- Compute CTR, CPC, ROAS ---
        kw_agg['ctr'] = kw_agg['clicks'] / kw_agg['impressions'].replace(0, 1)
        kw_agg['cpc'] = kw_agg['spend'] / kw_agg['clicks'].replace(0, 1)
        kw_agg['roas'] = kw_agg['sales'] / kw_agg['spend'].replace(0, 1)

        # --- Compute score out of 10 ---
        def compute_score(row):
            score = 0
            # CTR weighting (0-4 points)
            if row['ctr'] > 0.1:      score += 4
            elif row['ctr'] > 0.05:   score += 3
            elif row['ctr'] > 0.02:   score += 2
            elif row['ctr'] > 0:      score += 1

            # ROAS weighting (0-3 points)
            if row['roas'] > 5:       score += 3
            elif row['roas'] > 3:     score += 2
            elif row['roas'] > 1:     score += 1

            # Orders weighting (0-3 points)
            if row['orders'] > 20:    score += 3
            elif row['orders'] > 10:  score += 2
            elif row['orders'] > 0:   score += 1

            return min(score, 10)  # cap at 10

        kw_agg['score'] = kw_agg.apply(compute_score, axis=1)

        # --- Convert to list of dicts for JSON ---
        summary['keyword_performance'] = kw_agg.to_dict(orient='records')
        summary['keywords'] = kw_agg['customer_search_term'].tolist()

        conn.close()
        return summary

    except sqlite3.Error as e:
        print(f"Database error: {e}")
        return None
summary = get_campaign_summary_with_keyword_score('ads_data.db',"UTELT4BT2754-600GMBLACK - Group C")
print(json.dumps(summary, indent=4, sort_keys=True))
# Out:
# {
#     "campaign_info": {
#         "bidding_strategy": "Dynamic bids - down only",
#         "budget_amount": "$30.0",
#         "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#         "country": "United States",
#         "currency": "USD",
#         "portfolio_name": "Towel",
#         "program_type": "Sponsored Products",
#         "retailer": "Amazon",
#         "status": "ENABLED",
#         "targeting_type": "Manual targeting"
#     },
#     "campaign_performance": {
#         "7_day_total_orders_(#)": 76,
#         "7_day_total_sales": "$2964.02",
#         "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#         "click-thru_rate_(ctr)": "1.121%",
#         "clicks": 294,
#         "cost_per_click_(cpc)": "$1.5181973",
#         "end_date": "Jan 04, 2026",
#         "impressions": 26236,
#         "last_year_clicks": null,
#         "last_year_cost_per_click_(cpc)": "$0.0",
#         "last_year_impressions": null,
#         "last_year_spend": null,
#         "spend": "$446.35",
#         "start_date": "Dec 06, 2025",
#         "total_advertising_cost_of_sales_(acos)": "15.059000000000001%",
#         "total_return_on_advertising_spend_(roas)": 6.64
#     },
#     "keyword_performance": [
#         {
#             "clicks": 21,
#             "cpc": 1.9538095238095239,
#             "ctr": 0.015021459227467811,
#             "customer_search_term": "black towel",
#             "impressions": 1398,
#             "orders": 6,
#             "roas": 4.6015110894467455,
#             "sales": 188.79999999999998,
#             "score": 4,
#             "spend": 41.03
#         },
#         {
#             "clicks": 270,
#             "cpc": 1.4825185185185186,
#             "ctr": 0.012094064949608062,
#             "customer_search_term": "black towels",
#             "impressions": 22325,
#             "orders": 70,
#             "roas": 6.933196762266412,
#             "sales": 2775.22,
#             "score": 7,
#             "spend": 400.28000000000003
#         },
#         {
#             "clicks": 1,
#             "cpc": 3.04,
#             "ctr": 0.3333333333333333,
#             "customer_search_term": "black towels\ufffc",
#             "impressions": 3,
#             "orders": 0,
#             "roas": 0.0,
#             "sales": 0.0,
#             "score": 4,
#             "spend": 3.04
#         }
#     ],
#     "keywords": [
#         "black towel",
#         "black towels",
#         "black towels\ufffc"
#     ]
# }

# %%
def add_csv_to_sqlite(db_path, csv_path):
    """
    Reads a new CSV of keyword-level ad performance and inserts it into SQLite.
    Renames overlapping columns to avoid conflicts.
    """
    # --- Load CSV ---
    df = pd.read_csv(csv_path)

    # --- Define columns already in DB to rename ---
    existing_columns = [
        'campaign_name', 'ad_group_name', 'impressions', 'clicks', 'spend', 'sales', 'orders', 'units',
        'ctr', 'acos', 'cpc', 'roas', 'conversion_rate'
    ]

    # Map CSV columns to DB-friendly names
    rename_map = {}
    for col in df.columns:
        col_lower = col.lower().replace(' ', '_').replace('(informational_only)', '').replace('(', '').replace(')', '')
        # rename if conflicts
        if col_lower in existing_columns:
            rename_map[col] = f'ad_{col_lower}'
        else:
            rename_map[col] = col_lower

    df.rename(columns=rename_map, inplace=True)

    # --- Connect to SQLite ---
    conn = sqlite3.connect(db_path)

    # --- Write to DB ---
    df.to_sql('keyword_ad_performance', conn, if_exists='replace', index=False)

    conn.close()
    print("CSV added to SQLite table 'keyword_ad_performance' successfully!")

# -------------------------
# Example usage:
db_path = "ads_data.db"
csv_path = "bid_data.csv"
add_csv_to_sqlite(db_path, csv_path)
# Out:
# CSV added to SQLite table 'keyword_ad_performance' successfully!

# %%
def fill_null_bid_with_default(db_path):
    """
    Updates the 'keyword_ad_performance' table in SQLite:
    replaces NULL 'bid' values with 'ad_group_default_bid_' from the same row.
    """
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    try:
        cursor.execute("""
            UPDATE keyword_ad_performance
            SET bid = [ad_group_default_bid_]
            WHERE bid IS NULL;
        """)
        conn.commit()
        print(f"Updated {cursor.rowcount} rows with default bid.")
    except sqlite3.Error as e:
        print(f"Database error: {e}")
    finally:
        conn.close()

# -------------------------
# Example usage:
db_path = "ads_data.db"
fill_null_bid_with_default(db_path)
# Out:
# Updated 36599 rows with default bid.

# %%
def get_campaign_summary(db_path, campaign_name):
    """
    Returns a campaign summary:
    - campaign performance
    - campaign info
    - aggregated keyword performance
    - bid from keyword_ad_performance
    - score out of 10
    """
    summary = {}

    try:
        conn = sqlite3.connect(db_path)

        # --- Campaign performance ---
        campaign_perf = pd.read_sql_query(
            "SELECT * FROM CampaignPerformance WHERE campaign_name = ?",
            conn,
            params=(campaign_name,)
        )
        summary['campaign_performance'] = campaign_perf.to_dict(orient='records')[0] if not campaign_perf.empty else None

        # --- Campaign info ---
        campaign_info = pd.read_sql_query(
            "SELECT * FROM Campaign WHERE campaign_name = ?",
            conn,
            params=(campaign_name,)
        )
        summary['campaign_info'] = campaign_info.to_dict(orient='records')[0] if not campaign_info.empty else None

        # --- Keyword performance ---
        kw_perf = pd.read_sql_query(
            "SELECT * FROM KeywordPerformance WHERE campaign_name = ?",
            conn,
            params=(campaign_name,)
        )
        if kw_perf.empty:
            summary['keyword_performance'] = []
            summary['keywords'] = []
            conn.close()
            return summary

        # --- Aggregate metrics by ad_group_name + customer_search_term ---
        kw_agg = kw_perf.groupby(['ad_group_name', 'customer_search_term']).agg(
            impressions=pd.NamedAgg(column='impressions', aggfunc='sum'),
            clicks=pd.NamedAgg(column='clicks', aggfunc='sum'),
            spend=pd.NamedAgg(column='spend', aggfunc='sum'),
            sales=pd.NamedAgg(column='7_day_total_sales', aggfunc='sum'),
            orders=pd.NamedAgg(column='7_day_total_orders_#', aggfunc='sum')
        ).reset_index()

        # --- Compute CTR, CPC, ROAS ---
        kw_agg['ctr'] = kw_agg['clicks'] / kw_agg['impressions'].replace(0, 1)
        kw_agg['cpc'] = kw_agg['spend'] / kw_agg['clicks'].replace(0, 1)
        kw_agg['roas'] = kw_agg['sales'] / kw_agg['spend'].replace(0, 1)

        # --- Merge bid from keyword_ad_performance ---
        ad_perf = pd.read_sql_query(
            """
            SELECT campaign_name_ AS campaign_name,
                   ad_group_name_ AS ad_group_name,
                   keyword_text AS customer_search_term,
                   bid,
                   ad_group_default_bid_ AS default_bid
            FROM keyword_ad_performance
            WHERE campaign_name_ = ?
            """,
            conn,
            params=(campaign_name,)
        )

        # Fill missing bid with default bid
        ad_perf['bid'] = ad_perf['bid'].fillna(ad_perf['default_bid'])

        # Merge bids into aggregated keyword metrics
        kw_agg = kw_agg.merge(
            ad_perf[['ad_group_name', 'customer_search_term', 'bid']],
            on=['ad_group_name', 'customer_search_term'],
            how='left'
        )

        # --- Compute score out of 10 ---
        def compute_score(row):
            score = 0
            # CTR (0-4 points)
            if row['ctr'] > 0.1:      score += 4
            elif row['ctr'] > 0.05:   score += 3
            elif row['ctr'] > 0.02:   score += 2
            elif row['ctr'] > 0:      score += 1

            # ROAS (0-3 points)
            if row['roas'] > 5:       score += 3
            elif row['roas'] > 3:     score += 2
            elif row['roas'] > 1:     score += 1

            # Orders (0-3 points)
            if row['orders'] > 20:    score += 3
            elif row['orders'] > 10:  score += 2
            elif row['orders'] > 0:   score += 1

            return min(score, 10)

        kw_agg['score'] = kw_agg.apply(compute_score, axis=1)

        # --- Convert to JSON-friendly format ---
        summary['keyword_performance'] = kw_agg.to_dict(orient='records')
        summary['keywords'] = kw_agg['customer_search_term'].tolist()

        conn.close()
        return summary

    except sqlite3.Error as e:
        print(f"Database error: {e}")
        return None
        
summary = get_campaign_summary('ads_data.db',"UTELT4BT2754-600GMBLACK - Group C")
print(json.dumps(summary, indent=4, sort_keys=True))
# Out:
# {
#     "campaign_info": {
#         "bidding_strategy": "Dynamic bids - down only",
#         "budget_amount": "$30.0",
#         "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#         "country": "United States",
#         "currency": "USD",
#         "portfolio_name": "Towel",
#         "program_type": "Sponsored Products",
#         "retailer": "Amazon",
#         "status": "ENABLED",
#         "targeting_type": "Manual targeting"
#     },
#     "campaign_performance": {
#         "7_day_total_orders_(#)": 76,
#         "7_day_total_sales": "$2964.02",
#         "average_time_in_budget": "95.88%",
#         "campaign_name": "UTELT4BT2754-600GMBLACK - Group C",
#         "click-thru_rate_(ctr)": "1.121%",
#         "clicks": 294,
#         "cost_per_click_(cpc)": "$1.5181973",
#         "end_date": "Jan 04, 2026",
#         "impressions": 26236,
#         "last_year_clicks": null,
#         "last_year_cost_per_click_(cpc)": "$0.0",
#         "last_year_impressions": null,
#         "last_year_spend": null,
#         "spend": "$446.35",
#         "start_date": "Dec 06, 2025",
#         "total_advertising_cost_of_sales_(acos)": "15.059000000000001%",
#         "total_return_on_advertising_spend_(roas)": 6.64
#     },
#     "keyword_performance": [
#         {
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "bid": NaN,
#             "clicks": 21,
#             "cpc": 1.9538095238095239,
#             "ctr": 0.015021459227467811,
#             "customer_search_term": "black towel",
#             "impressions": 1398,
#             "orders": 6,
#             "roas": 4.6015110894467455,
#             "sales": 188.79999999999998,
#             "score": 4,
#             "spend": 41.03
#         },
#         {
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "bid": 0.91,
#             "clicks": 270,
#             "cpc": 1.4825185185185186,
#             "ctr": 0.012094064949608062,
#             "customer_search_term": "black towels",
#             "impressions": 22325,
#             "orders": 70,
#             "roas": 6.933196762266412,
#             "sales": 2775.22,
#             "score": 7,
#             "spend": 400.28000000000003
#         },
#         {
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "bid": 0.71,
#             "clicks": 270,
#             "cpc": 1.4825185185185186,
#             "ctr": 0.012094064949608062,
#             "customer_search_term": "black towels",
#             "impressions": 22325,
#             "orders": 70,
#             "roas": 6.933196762266412,
#             "sales": 2775.22,
#             "score": 7,
#             "spend": 400.28000000000003
#         },
#         {
#             "ad_group_name": "UTELT4BT2754-600GMBLACK",
#             "bid": NaN,
#             "clicks": 1,
#             "cpc": 3.04,
#             "ctr": 0.3333333333333333,
#             "customer_search_term": "black towels\ufffc",
#             "impressions": 3,
#             "orders": 0,
#             "roas": 0.0,
#             "sales": 0.0,
#             "score": 4,
#             "spend": 3.04
#         }
#     ],
#     "keywords": [
#         "black towel",
#         "black towels",
#         "black towels",
#         "black towels\ufffc"
#     ]
# }
