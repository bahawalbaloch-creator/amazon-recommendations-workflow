# %%
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("bid_data_only.csv")

# %%
df.head()
# Out:
#    Unnamed: 0             Entity  \
# 0          15  Product Targeting
# 1          16  Product Targeting
# 2          17  Product Targeting
# 3          18  Product Targeting
# 4          50  Product Targeting
#
#                  Campaign Name (Informational only)  \
# 0  NYTBATHROBEWOMENHOODSTEELGREY - Auto - Best Deal
# 1  NYTBATHROBEWOMENHOODSTEELGREY - Auto - Best Deal
# 2  NYTBATHROBEWOMENHOODSTEELGREY - Auto - Best Deal
# 3  NYTBATHROBEWOMENHOODSTEELGREY - Auto - Best Deal
# 4       UBCOTTONSQUAREPILLOW18x18 - Auto - Low Bids
#
#   Ad Group Name (Informational only) Portfolio Name (Informational only)  \
# 0                    BestDeal6-11-25                       Garments Team
# 1                    BestDeal6-11-25                       Garments Team
# 2                    BestDeal6-11-25                       Garments Team
# 3                    BestDeal6-11-25                       Garments Team
# 4          UBCOTTONSQUAREPILLOW18x18                             PILLOWS
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Entity', 'Campaign Name (Informational only)',
#        'Ad Group Name (Informational only)',
#        'Portfolio Name (Informational only)',
#        'Ad Group Default Bid (Informational only)', 'Bid',
#        'Product Targeting Expression',
#        'Resolved Product Targeting Expression (Informational only)',
#        'Impressions', 'Clicks', 'Click-through Rate', 'Spend', 'Sales',
#        'Orders', 'Units', 'Conversion Rate', 'ACOS', 'CPC', 'ROAS'],
#       dtype='object')

# %%
df[['Impressions',"Clicks","Sales","Orders","Bid","Ad Group Default Bid (Informational only)"]].head(3)
# Out:
#    Impressions  Clicks   Sales  Orders   Bid  \
# 0       209065     202  464.71      18  0.25
# 1          817       0    0.00       0  0.15
# 2         9669      84  554.91      25  0.26
#
#    Ad Group Default Bid (Informational only)
# 0                                       0.25
# 1                                       0.25
# 2                                       0.25
